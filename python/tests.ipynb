# %%
from sqlalchemy import create_engine

def get_connection():
    username = "root"
    password = "Abhishek1510"
    host = "localhost"
    database = "physio_analytics"

    engine = create_engine(
        f"mysql+pymysql://{username}:{password}@{host}/{database}"
    )

    return engine

# %%
from db_connection import get_connection

try:
    engine = get_connection()

    with engine.connect():
        print("SUCCESS")
except Exception as e:
    print("FAILED")
    print(e)
# Out:
# FAILED
# (pymysql.err.OperationalError) (2003, "Can't connect to MySQL server on '1510@localhost' ([Errno 11003] getaddrinfo failed)")
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
engine = create_engine(
    "mysql+pymysql://root:Abhishek1510@localhost/physio_analytics"
)

# %%
from sqlalchemy import create_engine
from sqlalchemy.engine import URL

url = URL.create(
    drivername="mysql+pymysql",
    username="root",
    password="Abhishek1510",
    host="localhost",
    database="physio_analytics"
)

print(url)

try:
    engine = create_engine(url)

    with engine.connect():
        print("SUCCESS")

except Exception as e:
    print("FAILED")
    print(e)
# Out:
# mysql+pymysql://root:***@localhost/physio_analytics
# SUCCESS
